# %% [markdown]
# ### Doc2Vec Model
#
# Gensim's Doc2Vec model vectorizes a group of words together rather than single words.
# [Source](https://www.machinelearningplus.com/nlp/gensim-tutorial/#15howtoupdateanexistingword2vecmodelwithnewdata)
#
# Code and idea adapted from the work of Clay Carson, Jollene Muncy and Cynthia Chiang.

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer
from gensim import corpora
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# read in raw data
data = pd.read_csv('./data/combined.csv')

# %%
# set display options to full column widths
pd.set_option('display.max_colwidth', None)

# %%
# define function to tokenize a column

def tokenizer_function(column):
    """
    Takes in a text column
        tokenizes the text in each row
        using pattern [[a-zA-Z]\w+]
        which matches every lowercase and upperase character between a-z that are word characters
    Returns list of strings
    """
    
    # instantiate empty list of tokenized text
    texts = []
    
    # define tokenizer pattern
    pattern = '[a-zA-Z]\w+'
    # instantiate tokenizer
    tokenizer = RegexpTokenizer(pattern=pattern)
    
    # create for loop to tokenize each row and add the list of tokens to texts
    for text in column:
        tokens = tokenizer.tokenize(text)
        
        # transform tokens into lower case strings
        tokens = [token.lower() for token in tokens]
        texts.append(tokens)
    return texts

# %%
# tokenize titles
tokenized_titles = tokenizer_function(data['title'])

# %%
type(tokenized_titles)
tokenized_titles[:2]
# Out:
# [['request',
#   'for',
#   'information',
#   'new',
#   'design',
#   'booklet',
#   'die',
#   'cutting',
#   'insert',
#   'assembly'],
#  ['audiovisual', 'suite', 'for', 'large', 'auditorium', 'maxwell', 'afb']]

# %% [markdown]
# **Create List of Tagged Documents**
#
# [Source](https://www.machinelearningplus.com/nlp/gensim-tutorial/#15howtoupdateanexistingword2vecmodelwithnewdata)

# %%
# define function to create tagged documents
def tag_documents(list_of_documents):
    """generator function
       accepts list of tokenized documents
       in form of list of list of words
       attaches tags to each document
       yields list of tagged documents"""
    for i, document in enumerate(list_of_documents):
        yield TaggedDocument(document, [i])

# %%
# tag documents
tagged_titles = list(tag_documents(tokenized_titles))

# %%
tagged_titles[:1]
# Out:
# [TaggedDocument(words=['request', 'for', 'information', 'new', 'design', 'booklet', 'die', 'cutting', 'insert', 'assembly'], tags=[0])]

# %% [markdown]
# **Create Doc2Vec Model**
#
# **--PV-DBOW, vector size = 50, epochs = 20--**

# %%
# Instantiate the Doc2Vec model
# skip-gram model
model = Doc2Vec(vector_size=50, dm=0, dbow_words=1, min_count=2, seed=1977, epochs=20)

# %%
# Build the Volabulary
model.build_vocab(tagged_titles)

# %%
# %%time
# Train the Doc2Vec model
model.train(tagged_titles, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# CPU times: user 1min 36s, sys: 10.8 s, total: 1min 47s
# Wall time: 1min 19s

# %%
# Save model for future use
model.save('doc2vec_titles')

# %%
# Load saved doc2vec_model
# model = Doc2Vec.load('doc2vec_titles')

# %% [markdown]
# **Get Similar Documents**

# %%
# get the 10 most similar documents to the first document
model.docvecs.most_similar(2530, topn=10)
# Out:
# [(36141, 0.8817406892776489),
#  (30384, 0.878228485584259),
#  (34781, 0.8750245571136475),
#  (25496, 0.8694334030151367),
#  (38220, 0.8674364686012268),
#  (42675, 0.8672429323196411),
#  (13667, 0.8621771335601807),
#  (35385, 0.8619729280471802),
#  (15634, 0.8584710359573364),
#  (15929, 0.856934130191803)]

# %% [markdown]
# **Let's investigate how similar these documents are**

# %%
# read in dataframe of contract notifications
data = pd.read_csv('./data/combined.csv')
data.sample(25)
# Out:
#                                noticeId  \
# 40819  dc5becef2cc64c46bd8306b130e084e6
# 21955  496f02eda0f94bd9a8b3e84b8a77815d
# 2530   61c2bdb4aee540a3bdf42a3886aca240
# 12098  e39501dbb64a451fb5b10c8f933ccd6e
# 38514  6ed1f768283b497bb19066368ecf53cd
# 40638  f8a0f16a5896412581cd81f84c552d3e
# 41257  99d96fbf1dee437b8acc864286598ba9
# 13097  ba00b2b5611d4153b5727a08cae93211
# 5186   12a2351eab5b4a2f96a309632d18c0e2
# 1367   055711e208e747198e7dac16ad315f14
# 36848  e83c93884bde471f99d94014a5d01d95
# 3575   74be71fee70949899dd02d3e9c0aa79b
# 13501  5fe5d0373c2d4b08857152def04ba01a
# 17810  0a0184bc4f88498788cd7669b63fc281
# 16672  ee5206bf930449e49e56f7ff15071cfe
# 5015   60c82d06f3264a40b4f96859e1928020
# 28311  703f354b83364364a113fd2d577f0092
# 25648  9356d143810042439995230c07ff7731
# 3151   2eba4b86231e464cb2298356af356d6b
# 21044  2446550c10e5485681db7d58bbfa22de
# 6046   4f53a7ddec0a4fbfaca8bb82424a3930
# 16743  dd7a02637e364d9d8524c17fa7594ca6
# 6839   72ce9d3c976047e39aef86392fc10b42
# 6647   dc4b119a188c4547b053ef87c28546e7
# 29266  a2b5b452c07d471d91e95b36259ed211
#
#                                                    title  \
# 40819                               56--VALVE BODY INSUL
# 21955                          47--ADAPTER,STRAIGHT,TUBE
# 2530                Kanopolis Lake Vegetation Management
# 12098                                    FD2020-20-00640
# 38514                            41--POSI-VAC STARTER KI
# 40638                            43--PUMP UNIT,CENTRIFUG
# 41257  Delivery Order for Class I Engineering Change ...
# 13097  Serena Software - Sole Source (Including Brand...
# 5186                                   Cisco ISE License
# 1367              USPSC- Knowledge Management Specialist
# 36848                             C-Cell  Food Structure
# 3575                                     47--TUBE,TORQUE
# 13501                            59--ATTENUATOR ASSEMBLY
# 17810                               47--HOSE,NONMETALLIC
# 16672                             15--BRACKET,STRUCTURAL
# 5015   Tree Removal for Jimmy Carter Plant Materials ...
# 28311  Take Charge and Move Out (TACAMO) Ground Commu...
# 25648  Aberdeen Proving Grounds (APG) Dispatch Consol...
# 3151                       FSC 1660  DUCT ASSEMBLY,AIR C
# 21044                             Kosher 4th Qtr FY 2020
# 6046     59--R/CR ASSEMBLY - AND OTHER REPLACEMENT PARTS
# 16743                            29--HARNESS ASSEMBLY,EL
# 6839                                47--HOSE,NONMETALLIC
# 6647                              47--SHIELD,SAFETY,PIPE
# 29266             W--SHOWERS AND PORTABLE TOILET SERVICE
#
#                   solicitationNumber                            department  \
# 40819                  N0010420QEF63                       DEPT OF DEFENSE
# 21955                  SPE7M320U0899                       DEPT OF DEFENSE
# 2530                   W912DQ20R1058                       DEPT OF DEFENSE
# 12098                            NaN                       DEPT OF DEFENSE
# 38514                  SPE8E820T3561                       DEPT OF DEFENSE
# 40638                  SPE7M120T438A                       DEPT OF DEFENSE
# 41257  N00019-20-RFPREQ-PMA-201-0259                       DEPT OF DEFENSE
# 13097                  FA300220Q0006                       DEPT OF DEFENSE
# 5186                   N0025320Q0097                       DEPT OF DEFENSE
# 1367                  7200AA20R00045  AGENCY FOR INTERNATIONAL DEVELOPMENT
# 36848               126612-20-Q-0021            AGRICULTURE, DEPARTMENT OF
# 3575                   SPE4A520T331G                       DEPT OF DEFENSE
# 13501                  SPE7M520Q0825                       DEPT OF DEFENSE
# 17810                  N0010420QEE26                       DEPT OF DEFENSE
# 16672                  SPE4A720R0094                       DEPT OF DEFENSE
# 5015                   12FPC120Q0010            AGRICULTURE, DEPARTMENT OF
# 28311               N66001-20-R-0189                       DEPT OF DEFENSE
# 25648               W52P1J-20-C-0017                       DEPT OF DEFENSE
# 3151                   SPE4A720R0688                       DEPT OF DEFENSE
# 21044              15B21320Q00000020                JUSTICE, DEPARTMENT OF
# 6046                   SPRMM120QPB79                       DEPT OF DEFENSE
# 16743                  SPE5E820U0181                       DEPT OF DEFENSE
# 6839                   SPE7M320U0649                       DEPT OF DEFENSE
# 6647                   SPE7M320U0600                       DEPT OF DEFENSE
# 29266               N6883620Q0062_01                       DEPT OF DEFENSE
#
#                                                 subTier  \
# 40819                                  DEPT OF THE NAVY
# 21955                    DEFENSE LOGISTICS AGENCY (DLA)
# 2530                                   DEPT OF THE ARMY
# 12098                             DEPT OF THE AIR FORCE
# 38514                    DEFENSE LOGISTICS AGENCY (DLA)
# 40638                    DEFENSE LOGISTICS AGENCY (DLA)
# 41257                                  DEPT OF THE NAVY
# 13097                             DEPT OF THE AIR FORCE
# 5186                                   DEPT OF THE NAVY
# 1367               AGENCY FOR INTERNATIONAL DEVELOPMENT
# 36848                     AGRICULTURAL RESEARCH SERVICE
# 3575                     DEFENSE LOGISTICS AGENCY (DLA)
# 13501                    DEFENSE LOGISTICS AGENCY (DLA)
# 17810                                  DEPT OF THE NAVY
# 16672                    DEFENSE LOGISTICS AGENCY (DLA)
# 5015   FARM PRODUCTION AND CONSERVATION BUSINESS CENTER
# 28311                                  DEPT OF THE NAVY
# 25648                                  DEPT OF THE ARMY
# 3151                     DEFENSE LOGISTICS AGENCY (DLA)
# 21044         FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 6046                     DEFENSE LOGISTICS AGENCY (DLA)
# 16743                    DEFENSE LOGISTICS AGENCY (DLA)
# 6839                     DEFENSE LOGISTICS AGENCY (DLA)
# 6647                     DEFENSE LOGISTICS AGENCY (DLA)
# 29266                                  DEPT OF THE NAVY
#
#                                    office  postedDate  \
# 40819  NAVSUP WEAPON SYSTEMS SUPPORT MECH  2020-05-28
# 21955               DLA LAND AND MARITIME  2020-05-07
# 2530              W071 ENDIST KANSAS CITY  2020-04-22
# 12098                 FA8221 AFNWC   PZBB  2020-03-11
# 38514                   DLA TROOP SUPPORT  2020-05-18
# 40638               DLA LAND AND MARITIME  2020-05-28
# 41257           NAVAL AIR SYSTEMS COMMAND  2020-05-28
# 13097                FA3002  338 SCONS CC  2020-04-29
# 5186        NAVAL UNDERSEA WARFARE CENTER  2020-04-16
# 1367                          USAID M/OAA  2020-04-24
# 36848                  USDA ARS PA RRVARC  2020-05-19
# 3575                         DLA AVIATION  2020-04-20
# 13501               DLA LAND AND MARITIME  2020-04-29
# 17810  NAVSUP WEAPON SYSTEMS SUPPORT MECH  2020-05-13
# 16672                        DLA AVIATION  2020-05-13
# 5015                FPAC BUS CNTR-ACQ DIV  2020-04-16
# 28311                        NIWC PACIFIC  2020-02-13
# 25648                         W6QK ACC-RI  2020-05-01
# 3151                         DLA AVIATION  2020-04-21
# 21044                      FCI SCHUYLKILL  2020-05-08
# 6046             SPRMM1 DLA MECHANICSBURG  2020-04-14
# 16743                   DLA TROOP SUPPORT  2020-05-13
# 6839                DLA LAND AND MARITIME  2020-04-12
# 6647                DLA LAND AND MARITIME  2020-04-12
# 29266     NAVSUP FLT LOG CTR JACKSONVILLE  2020-01-24
#
#                                  type                        baseType  \
# 40819                    Solicitation                    Solicitation
# 21955  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 2530   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 12098                  Special Notice                  Special Notice
# 38514  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 40638  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 41257                 Presolicitation                 Presolicitation
# 13097                   Justification                   Justification
# 5186   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 1367                     Solicitation                    Solicitation
# 36848                    Solicitation                    Solicitation
# 3575   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 13501  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 17810                 Presolicitation                 Presolicitation
# 16672                    Award Notice                    Award Notice
# 5015   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 28311                 Presolicitation                 Presolicitation
# 25648                   Justification                 Presolicitation
# 3151                  Presolicitation                 Presolicitation
# 21044  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 6046                     Solicitation                    Solicitation
# 16743  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 6839   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 6647   Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 29266  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
#
#       archiveType  ...                                              award  \
# 40819      auto15  ...                      {'awardee': {'location': {}}}
# 21955  autocustom  ...                      {'awardee': {'location': {}}}
# 2530   autocustom  ...                                                NaN
# 12098  autocustom  ...                                                NaN
# 38514  autocustom  ...                      {'awardee': {'location': {}}}
# 40638  autocustom  ...                      {'awardee': {'location': {}}}
# 41257  autocustom  ...                                                NaN
# 13097      auto30  ...  {'date': '2020-04-23', 'number': 'FA300220C0009'}
# 5186   autocustom  ...                                                NaN
# 1367       auto15  ...                                                NaN
# 36848      auto15  ...                                                NaN
# 3575   autocustom  ...                      {'awardee': {'location': {}}}
# 13501  autocustom  ...                      {'awardee': {'location': {}}}
# 17810  autocustom  ...                      {'awardee': {'location': {}}}
# 16672      auto15  ...  {'date': '2020-05-13', 'number': 'SPE4A720D024...
# 5015       auto15  ...                                                NaN
# 28311  autocustom  ...                      {'awardee': {'location': {}}}
# 25648      auto30  ...  {'date': '2020-04-30', 'number': 'W52P1J-20-C-...
# 3151   autocustom  ...                                                NaN
# 21044  autocustom  ...                                                NaN
# 6046       auto15  ...                      {'awardee': {'location': {}}}
# 16743  autocustom  ...                      {'awardee': {'location': {}}}
# 6839   autocustom  ...                      {'awardee': {'location': {}}}
# 6647   autocustom  ...                      {'awardee': {'location': {}}}
# 29266  autocustom  ...                      {'awardee': {'location': {}}}
#
#                                           pointOfContact  \
# 40819  [{'fax': None, 'type': 'primary', 'email': 'LY...
# 21955  [{'fax': None, 'type': 'primary', 'email': 'Di...
# 2530   [{'fax': '', 'type': 'primary', 'email': 'laur...
# 12098                                                NaN
# 38514  [{'fax': None, 'type': 'primary', 'email': 'Di...
# 40638  [{'fax': None, 'type': 'primary', 'email': 'Di...
# 41257  [{'fax': '', 'type': 'primary', 'email': 'sama...
# 13097  [{'fax': None, 'type': 'primary', 'email': 'gr...
# 5186   [{'fax': '', 'type': 'primary', 'email': 'murr...
# 1367   [{'fax': '', 'type': 'primary', 'email': 'jbui...
# 36848  [{'fax': 'Not accepted', 'type': 'primary', 'e...
# 3575   [{'fax': None, 'type': 'primary', 'email': 'Di...
# 13501  [{'fax': None, 'type': 'primary', 'email': 'Di...
# 17810  [{'fax': None, 'type': 'primary', 'email': 'AB...
# 16672  [{'fax': None, 'type': 'primary', 'email': 'Ci...
# 5015   [{'fax': '', 'type': 'primary', 'email': 'dann...
# 28311  [{'fax': None, 'type': 'primary', 'email': 'as...
# 25648  [{'fax': None, 'type': 'primary', 'email': 'kr...
# 3151   [{'fax': '', 'type': 'primary', 'email': 'sara...
# 21044  [{'fax': '5705447198', 'type': 'primary', 'ema...
# 6046   [{'fax': None, 'type': 'primary', 'email': 'AM...
# 16743  [{'fax': None, 'type': 'primary', 'email': 'Di...
# 6839   [{'fax': None, 'type': 'primary', 'email': 'Di...
# 6647   [{'fax': None, 'type': 'primary', 'email': 'Di...
# 29266  [{'fax': None, 'type': 'primary', 'email': 'ma...
#
#                                              description organizationType  \
# 40819  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 21955  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 2530   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 12098  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 38514  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 40638  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 41257  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 13097  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 5186   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 1367   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 36848  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 3575   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 13501  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 17810  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 16672  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 5015   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 28311  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 25648  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 3151   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 21044  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 6046   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 16743  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 6839   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 6647   https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 29266  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
#
#                                            officeAddress  \
# 40819  {'zipcode': '17050-0788', 'city': 'MECHANICSBU...
# 21955  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 2530   {'zipcode': '64106-2896', 'city': 'KANSAS CITY...
# 12098  {'zipcode': '84056-5837', 'city': 'HILL AFB', ...
# 38514  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
# 40638  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 41257  {'zipcode': '20670-5000', 'city': 'PATUXENT RI...
# 13097  {'zipcode': '78150-4300', 'city': 'RANDOLPH AF...
# 5186   {'zipcode': '98345-7610', 'city': 'KEYPORT', '...
# 1367   {'zipcode': '20523', 'city': 'WASHINGTON', 'co...
# 36848  {'zipcode': '58102', 'city': 'FARGO', 'country...
# 3575   {'zipcode': '23297', 'city': 'RICHMOND', 'coun...
# 13501  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 17810  {'zipcode': '17050-0788', 'city': 'MECHANICSBU...
# 16672  {'zipcode': '23297', 'city': 'RICHMOND', 'coun...
# 5015   {'zipcode': '20250', 'city': 'WASHINGTON', 'co...
# 28311  {'zipcode': '92152-5001', 'city': 'SAN DIEGO',...
# 25648  {'zipcode': '61299-5000', 'city': 'ROCK ISLAND...
# 3151   {'zipcode': '23297', 'city': 'RICHMOND', 'coun...
# 21044  {'zipcode': '17954', 'city': 'MINERSVILLE', 'c...
# 6046   {'zipcode': '17055-0788', 'city': 'MECHANICSBU...
# 16743  {'zipcode': '19111', 'city': 'PHILADELPHIA', '...
# 6839   {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 6647   {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 29266  {'zipcode': '32212-0097', 'city': 'JACKSONVILL...
#
#                                       placeOfPerformance additionalInfoLink  \
# 40819                                                 {}                NaN
# 21955                                                 {}                NaN
# 2530                                                 NaN                NaN
# 12098                                                NaN                NaN
# 38514                                                 {}                NaN
# 40638                                                 {}                NaN
# 41257  {'city': {'code': '65000', 'name': 'Saint Loui...                NaN
# 13097  {'city': {'code': 'TX-18', 'name': 'JBSA Rando...                NaN
# 5186                                                 NaN                NaN
# 1367   {'city': {'code': '50000', 'name': 'Washington...                NaN
# 36848  {'city': {'code': '25700', 'name': 'Fargo'}, '...                NaN
# 3575                                                  {}                NaN
# 13501                                                 {}                NaN
# 17810                                                 {}                NaN
# 16672                                                 {}                NaN
# 5015   {'state': {'code': 'GA', 'name': 'Georgia'}, '...                NaN
# 28311                                                 {}                NaN
# 25648  {'city': {'code': '175', 'name': 'Aberdeen Pro...                NaN
# 3151                                                 NaN                NaN
# 21044  {'city': {'code': '50088', 'name': 'Minersvill...                NaN
# 6046                                                  {}                NaN
# 16743                                                 {}                NaN
# 6839                                                  {}                NaN
# 6647                                                  {}                NaN
# 29266     {'streetAddress': 'See Place of Performance.'}                NaN
#
#                                                   uiLink  \
# 40819  https://beta.sam.gov/opp/dc5becef2cc64c46bd830...
# 21955  https://beta.sam.gov/opp/496f02eda0f94bd9a8b3e...
# 2530   https://beta.sam.gov/opp/61c2bdb4aee540a3bdf42...
# 12098  https://beta.sam.gov/opp/e39501dbb64a451fb5b10...
# 38514  https://beta.sam.gov/opp/6ed1f768283b497bb1906...
# 40638  https://beta.sam.gov/opp/f8a0f16a5896412581cd8...
# 41257  https://beta.sam.gov/opp/99d96fbf1dee437b8acc8...
# 13097  https://beta.sam.gov/opp/ba00b2b5611d4153b5727...
# 5186   https://beta.sam.gov/opp/12a2351eab5b4a2f96a30...
# 1367   https://beta.sam.gov/opp/055711e208e747198e7da...
# 36848  https://beta.sam.gov/opp/e83c93884bde471f99d94...
# 3575   https://beta.sam.gov/opp/74be71fee70949899dd02...
# 13501  https://beta.sam.gov/opp/5fe5d0373c2d4b0885715...
# 17810  https://beta.sam.gov/opp/0a0184bc4f88498788cd7...
# 16672  https://beta.sam.gov/opp/ee5206bf930449e49e56f...
# 5015   https://beta.sam.gov/opp/60c82d06f3264a40b4f96...
# 28311  https://beta.sam.gov/opp/703f354b83364364a113f...
# 25648  https://beta.sam.gov/opp/9356d1438100424399952...
# 3151   https://beta.sam.gov/opp/2eba4b86231e464cb2298...
# 21044  https://beta.sam.gov/opp/2446550c10e5485681db7...
# 6046   https://beta.sam.gov/opp/4f53a7ddec0a4fbfaca8b...
# 16743  https://beta.sam.gov/opp/dd7a02637e364d9d8524c...
# 6839   https://beta.sam.gov/opp/72ce9d3c976047e39aef8...
# 6647   https://beta.sam.gov/opp/dc4b119a188c4547b053e...
# 29266  https://beta.sam.gov/opp/a2b5b452c07d471d91e95...
#
#                                                    links  \
# 40819  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 21955  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 2530   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 12098  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 38514  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 40638  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 41257  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 13097  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 5186   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 1367   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 36848  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 3575   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 13501  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 17810  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 16672  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 5015   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 28311  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 25648  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 3151   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 21044  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 6046   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 16743  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 6839   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 6647   [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 29266  [{'rel': 'self', 'href': 'https://api.sam.gov/...
#
#                                            resourceLinks
# 40819                                                NaN
# 21955                                                NaN
# 2530   ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 12098  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 38514                                                NaN
# 40638                                                NaN
# 41257                                                NaN
# 13097  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 5186   ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 1367   ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 36848  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 3575                                                 NaN
# 13501                                                NaN
# 17810                                                NaN
# 16672                                                NaN
# 5015   ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 28311                                                NaN
# 25648  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 3151                                                 NaN
# 21044  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 6046                                                 NaN
# 16743                                                NaN
# 6839                                                 NaN
# 6647                                                 NaN
# 29266                                                NaN
#
# [25 rows x 27 columns]

# %%
# find most similar documents in dataframe
def most_similar(path_to_model, base_document_idx, n):
    """function
       finds most similar n documents
       to base_document
       based on cosine similarity
       returns similar documents 
       as pandas dataframe"""
    # load saved doc2vec_model
    model = Doc2Vec.load(path_to_model)
    # get similar topics
    similars = model.docvecs.most_similar(base_document_idx, topn=n)
    
    # load original dataframe
    data = pd.read_csv('./data/combined.csv')
    # base document
    row1 = data.loc[base_document_idx, ['title', 'department', 'uiLink']]
    
    # list of rows in the original dataframe
    # initialized with the base_document
    list_of_dfs = [row1]
    
    # iterate through all similar notifications
    for tag, similar_document in similars:
        # find the row in the notifications dataframe corresponding to the tag
        df = data.loc[tag, ['title', 'department', 'uiLink']]
        # add row to the list of rows 
        list_of_dfs.append(df)
    # return all rows as a dataframe   
    return pd.DataFrame(list_of_dfs)

# %%
# show most similar 10 titles to the notification indexed 2530
path = 'doc2vec_titles'
most_similar(path, 2530, 10)
# Out:
#                                           title                   department  \
# 2530       Kanopolis Lake Vegetation Management              DEPT OF DEFENSE
# 36141            Canada Geese Hazard Management              DEPT OF DEFENSE
# 30384  Forestry Vegetation Management Treatment   AGRICULTURE, DEPARTMENT OF
# 34781             Benbrook Lake Mowing Services              DEPT OF DEFENSE
# 25496                       Vegetation Services              DEPT OF DEFENSE
# 38220                             Tree Spraying   AGRICULTURE, DEPARTMENT OF
# 42675  Law Enforcement Services Coralville Lake              DEPT OF DEFENSE
# 13667             Security Gates, Lake Mead NRA  INTERIOR, DEPARTMENT OF THE
# 35385     Fee Collector Services, Lake Ouachita              DEPT OF DEFENSE
# 15634      Herbicide Services, RS Kerr Lake, OK              DEPT OF DEFENSE
# 15929      Herbicide Services, RS Kerr Lake, OK              DEPT OF DEFENSE
#
#                                                                uiLink
# 2530   https://beta.sam.gov/opp/61c2bdb4aee540a3bdf42a3886aca240/view
# 36141  https://beta.sam.gov/opp/7e34e5089a904354a45f0f1ca1b48f01/view
# 30384  https://beta.sam.gov/opp/afb469ce250d4ef2bcacf858b89832c0/view
# 34781  https://beta.sam.gov/opp/61ba07930a6f4a1986325a9bf3f3948e/view
# 25496  https://beta.sam.gov/opp/da7ea2a5c4f344ef898e254bff65be8e/view
# 38220  https://beta.sam.gov/opp/b8ba6114df5248c9a9b949edc9754ed4/view
# 42675  https://beta.sam.gov/opp/ca9e5cba5c494956b5a4b4b21023b71d/view
# 13667  https://beta.sam.gov/opp/38799521cff148d487c6ba68b59a55b7/view
# 35385  https://beta.sam.gov/opp/111ce7e61c4847878b32f4aaee12ab65/view
# 15634  https://beta.sam.gov/opp/ae7f38a4152d4b6783694779e90acbce/view
# 15929  https://beta.sam.gov/opp/783a2b0ee9824f988c292f594485c062/view

# %% [markdown]
# **Create Doc2Vec Model**
#
# **--PV-DM, vector size = 100, epochs = 20--**

# %%
# Instantiate the Doc2Vec model
# cbow model
model_cbow = Doc2Vec(vector_size=100, dm=1, dbow_words=0, seed=1977, epochs=20)

# %%
# Build the Volabulary
model_cbow.build_vocab(tagged_titles)

# %%
# %%time
# Train the Doc2Vec model
model_cbow.train(tagged_titles, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# CPU times: user 1min 17s, sys: 10.7 s, total: 1min 28s
# Wall time: 1min 18s

# %%
# Save model for future use
model_cbow.save('doc2vec_cbow_titles')

# %%
# Load saved doc2vec_model
# model = Doc2Vec.load('doc2vec_cbow_titles')

# %% [markdown]
# **Get Similar Documents**

# %%
# get the 10 most similar documents to the first document
model_cbow.docvecs.most_similar(2530, topn=10)
# Out:
# [(6245, 0.7212549448013306),
#  (38114, 0.6974656581878662),
#  (10881, 0.6973400115966797),
#  (12427, 0.6951607465744019),
#  (41082, 0.6848417520523071),
#  (45302, 0.6625716090202332),
#  (10627, 0.6494672298431396),
#  (13389, 0.6357793807983398),
#  (12426, 0.634731650352478),
#  (22228, 0.6210447549819946)]

# %%
path_cbow = 'doc2vec_cbow_titles'
most_similar(path_cbow, 2530, 10)
# Out:
#                                                                                                                                                                                       title  \
# 2530                                                                                                                                                   Kanopolis Lake Vegetation Management
# 6245                                                                                                                                 Battle Creek Environmental Compliance and Commitments
# 38114                                                                                                                 R--Glen Canyon Dam Adaptive Management Program - Meeting Facilitation
# 10881                                                                                                                                    Fire Management Complex Janitorial Services, Lewis
# 12427                                                                                                                    Technical Support for Coast Guard Ballast Water Management Program
# 41082                                                                                                                                                   ARNG-CSO-F Dock Management Services
# 45302                                                                                                       58--NETWORK MANAGEMENT - AND OTHER REPLACEMENT PARTS, IN REPAIR/MODIFICATION OF
# 10627                                                              R--Enterprise Progran Management Office (EPMO) Technical & Business Management Support - Base Period (VA-20-00031624)
# 13389                                                                                                                                 Agency Strategic Business Management Support Services
# 12426  Combined Services (Gate Attendant, Mowing and Trimming and Solid Waste Removal Services) for Tar Camp Park & Dam Site 5 Park within the responsibility of the Pine Bluff Site Office
# 22228                                                                    Centralized Database for Hazard Communication Program, Chemical Inventory and Safety Data Sheet (SDS) Management
#
#                             department  \
# 2530                   DEPT OF DEFENSE
# 6245       INTERIOR, DEPARTMENT OF THE
# 38114      INTERIOR, DEPARTMENT OF THE
# 10881      INTERIOR, DEPARTMENT OF THE
# 12427    TRANSPORTATION, DEPARTMENT OF
# 41082                  DEPT OF DEFENSE
# 45302                  DEPT OF DEFENSE
# 10627  VETERANS AFFAIRS, DEPARTMENT OF
# 13389                  DEPT OF DEFENSE
# 12426                  DEPT OF DEFENSE
# 22228    TRANSPORTATION, DEPARTMENT OF
#
#                                                                uiLink
# 2530   https://beta.sam.gov/opp/61c2bdb4aee540a3bdf42a3886aca240/view
# 6245   https://beta.sam.gov/opp/d636876ff5d44cf29ec05482ef2c04b2/view
# 38114  https://beta.sam.gov/opp/d2cc833ca9e648718abcdb51711bbec7/view
# 10881  https://beta.sam.gov/opp/1d79193e417442f8a701f1e3c21c7781/view
# 12427  https://beta.sam.gov/opp/61631a2abffe413a9ff5cc3e39e31d73/view
# 41082  https://beta.sam.gov/opp/b41bcbc3d63d406cb49073d646747934/view
# 45302  https://beta.sam.gov/opp/8bcac9882c4c4d5b93937caf735a8897/view
# 10627  https://beta.sam.gov/opp/e5543506b0c54432aa040ad8563b6ca3/view
# 13389  https://beta.sam.gov/opp/78fe435d19e046dcab8cab4fe52104f3/view
# 12426  https://beta.sam.gov/opp/617f443b45384ae6a9d93f88cb2b2dca/view
# 22228  https://beta.sam.gov/opp/0d6b7523dbc34f71a8baceacb6f3337b/view

# %% [markdown]
# **Get Similar Words**

# %%
# inspect the vocabulary

vocabulary = model.wv.vocab
# vocabulary

# %%
# get the first 10 items in the vocabulary
list(vocabulary.keys())[:10]
# Out:
# ['request',
#  'for',
#  'information',
#  'new',
#  'design',
#  'booklet',
#  'die',
#  'cutting',
#  'insert',
#  'assembly']

# %%
# get the frequency of a word in the corpus 
model.wv.vocab['request'].count
# Out:
# 328

# %%
# get words similar to the entry term with their cosine similarity scores
model.wv.most_similar_cosmul('request')
# Out:
# [('information', 0.9256718158721924),
#  ('proposals', 0.8846799731254578),
#  ('agv', 0.8732286691665649),
#  ('ppb2', 0.8524883389472961),
#  ('r420', 0.849981427192688),
#  ('adhesives', 0.8489277958869934),
#  ('cornerstone', 0.8470085859298706),
#  ('acclimation', 0.8461048007011414),
#  ('papers', 0.8448440432548523),
#  ('infill', 0.8435037732124329)]

# %% [markdown]
# The list of most similar words to request in the document is promising, but it could be better. More text cleaning is needed.

# %% [markdown]
# ---
# **Note:** I tested the two Doc2Vec models on the same document. The two models found different documents to be most similar to the same base document. However, performing a common sense check on both sets of similar documents suggests that the documents the two models recommended were equally relevant. The PV-DBOW model, however, produced higher similarity scores. Therefore, I used that model in my recommender.
