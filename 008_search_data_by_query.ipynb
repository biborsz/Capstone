# %%
import pandas as pd
from nltk.tokenize import RegexpTokenizer

# %%
df = pd.read_csv('./data/combined.csv')
df.head()
# Out:
#                            noticeId  \
# 0  ffe3c07bab8b4a7d9be583fd4dd96c4a
# 1  ff5e29951ed14b0386ea3291fa6c573f
# 2  ff2a16aad70246d1ba10e639c11456d4
# 3  fef5aeb716414feb8c12eec5e5063ff6
# 4  fed3bef7bd1e4ac389950ef7a087e578
#
#                                                title solicitationNumber  \
# 0  REQUEST FOR INFORMATION - NEW DESIGN BOOKLET D...         RFI-042720
# 1  Audiovisual Suite for Large Auditorium - Maxwe...      FA330020X0001
# 2                           Metrology Equipment Move   SP4703-20-Q-0045
# 3                  INNER INFLATABLE ASSY (LPU-36A/P)       PR1000092966
# 4                                         17--CRADLE      SPE8EF20T1468
#
#                                    department  \
# 0  UNITED STATES GOVERNMENT PUBLISHING OFFICE
# 1                             DEPT OF DEFENSE
# 2                             DEPT OF DEFENSE
# 3                             DEPT OF DEFENSE
# 4                             DEPT OF DEFENSE
#
#                                       subTier                 office  \
# 0  UNITED STATES GOVERNMENT PUBLISHING OFFICE   Acquisition Services
# 1                       DEPT OF THE AIR FORCE     FA3300  42 CONS CC
# 2              DEFENSE LOGISTICS AGENCY (DLA)          DCSO RICHMOND
# 3              DEFENSE LOGISTICS AGENCY (DLA)  DLA LAND AND MARITIME
# 4              DEFENSE LOGISTICS AGENCY (DLA)      DLA TROOP SUPPORT
#
#    postedDate                            type                        baseType  \
# 0  2020-04-27                  Sources Sought                  Sources Sought
# 1  2020-04-27                  Sources Sought                  Sources Sought
# 2  2020-04-27  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 3  2020-04-27                  Sources Sought                  Sources Sought
# 4  2020-04-27  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
#
#   archiveType  ...                          award  \
# 0      auto15  ...                            NaN
# 1      auto15  ...                            NaN
# 2      auto15  ...                            NaN
# 3      auto15  ...                            NaN
# 4  autocustom  ...  {'awardee': {'location': {}}}
#
#                                       pointOfContact  \
# 0  [{'fax': '', 'type': 'primary', 'email': 'rgra...
# 1  [{'fax': '3349532198', 'type': 'primary', 'ema...
# 2  [{'fax': '', 'type': 'primary', 'email': 'Kiar...
# 3  [{'fax': '', 'type': 'primary', 'email': 'mind...
# 4  [{'fax': None, 'type': 'primary', 'email': 'Di...
#
#                                          description organizationType  \
# 0  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 1  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 2  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 3  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 4  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
#
#                                        officeAddress  \
# 0  {'zipcode': '20401', 'city': 'Washington', 'co...
# 1  {'zipcode': '36112-6334', 'city': 'MAXWELL AFB...
# 2  {'zipcode': '23297-5441', 'city': 'RICHMOND', ...
# 3  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 4  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
#
#                                   placeOfPerformance additionalInfoLink  \
# 0  {'state': {'code': 'DC', 'name': 'District of ...                NaN
# 1  {'city': {'code': '51000', 'name': 'Montgomery...                NaN
# 2  {'city': {'code': '67000', 'name': 'Richmond'}...                NaN
# 3                                                NaN                NaN
# 4                                                 {}                NaN
#
#                                               uiLink  \
# 0  https://beta.sam.gov/opp/ffe3c07bab8b4a7d9be58...
# 1  https://beta.sam.gov/opp/ff5e29951ed14b0386ea3...
# 2  https://beta.sam.gov/opp/ff2a16aad70246d1ba10e...
# 3  https://beta.sam.gov/opp/fef5aeb716414feb8c12e...
# 4  https://beta.sam.gov/opp/fed3bef7bd1e4ac389950...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 1  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 2  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 3  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 4  [{'rel': 'self', 'href': 'https://api.sam.gov/...
#
#                                        resourceLinks
# 0  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 1  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 2  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 27 columns]

# %%
# define function to tokenize a column 
# modified to return title cased titles

def tokenizer_function(column):
    """
    Takes in a text column
        tokenizes the text in each row
        using pattern [[a-zA-Z]\w+]
        which matches every lowercase and upperase character between a-z that are word characters
    Returns list of strings
    """
    
    # instantiate empty list of tokenized text
    texts = []
    
    # define tokenizer pattern
    pattern = '[a-zA-Z]\w+'
    # instantiate tokenizer
    tokenizer = RegexpTokenizer(pattern=pattern)
    
    # create for loop to tokenize each row and add the list of tokens to texts
    for text in column:
        tokens = tokenizer.tokenize(text)
        
        # transform tokens into lower case strings
        tokens = [token.title() for token in tokens]
        texts.append(' '.join(tokens))
    return texts

# %%
df['cleaned_titles'] = tokenizer_function(df['title'])

# %%
df.to_csv('./data/combined.csv', index=False)

# %%
for i in range(5):
    print(df.index[i], df['cleaned_titles'][i])
# Out:
# 0 Request For Information New Design Booklet Die Cutting Insert Assembly
# 1 Audiovisual Suite For Large Auditorium Maxwell Afb
# 2 Metrology Equipment Move
# 3 Inner Inflatable Assy Lpu
# 4 Cradle

# %%
cleaned_titles[:5]
# Out:
# ['Request For Information New Design Booklet Die Cutting Insert Assembly',
#  'Audiovisual Suite For Large Auditorium Maxwell Afb',
#  'Metrology Equipment Move',
#  'Inner Inflatable Assy Lpu',
#  'Cradle']

# %%
# define function to search titles based on search term
# return titles that contain the search term
# the number of titles returned are specified by 'number'
def search_by_query(search_term):
#     df = pd.read_csv('../../data/combined.csv')
#     from ..(path to tokenizer function) import tokenizer_function
    df['cleaned_titles'] = tokenizer_function(df['title'])
    df_to_return = pd.DataFrame()
    for i in range(len(df)):
        if search_term.lower() in df['cleaned_titles'][i].lower():
            title = df['cleaned_titles'][i]
            
            if len(df_to_return) == 0 or title not in df_to_return['cleaned_titles'].values:
                df_to_return = df_to_return.append(df.loc[[i]])

    
    return df_to_return

# %%
df.head()
# Out:
#                            noticeId  \
# 0  ffe3c07bab8b4a7d9be583fd4dd96c4a
# 1  ff5e29951ed14b0386ea3291fa6c573f
# 2  ff2a16aad70246d1ba10e639c11456d4
# 3  fef5aeb716414feb8c12eec5e5063ff6
# 4  fed3bef7bd1e4ac389950ef7a087e578
#
#                                                title solicitationNumber  \
# 0  REQUEST FOR INFORMATION - NEW DESIGN BOOKLET D...         RFI-042720
# 1  Audiovisual Suite for Large Auditorium - Maxwe...      FA330020X0001
# 2                           Metrology Equipment Move   SP4703-20-Q-0045
# 3                  INNER INFLATABLE ASSY (LPU-36A/P)       PR1000092966
# 4                                         17--CRADLE      SPE8EF20T1468
#
#                                    department  \
# 0  UNITED STATES GOVERNMENT PUBLISHING OFFICE
# 1                             DEPT OF DEFENSE
# 2                             DEPT OF DEFENSE
# 3                             DEPT OF DEFENSE
# 4                             DEPT OF DEFENSE
#
#                                       subTier                 office  \
# 0  UNITED STATES GOVERNMENT PUBLISHING OFFICE   Acquisition Services
# 1                       DEPT OF THE AIR FORCE     FA3300  42 CONS CC
# 2              DEFENSE LOGISTICS AGENCY (DLA)          DCSO RICHMOND
# 3              DEFENSE LOGISTICS AGENCY (DLA)  DLA LAND AND MARITIME
# 4              DEFENSE LOGISTICS AGENCY (DLA)      DLA TROOP SUPPORT
#
#    postedDate                            type                        baseType  \
# 0  2020-04-27                  Sources Sought                  Sources Sought
# 1  2020-04-27                  Sources Sought                  Sources Sought
# 2  2020-04-27  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
# 3  2020-04-27                  Sources Sought                  Sources Sought
# 4  2020-04-27  Combined Synopsis/Solicitation  Combined Synopsis/Solicitation
#
#   archiveType  ...                                     pointOfContact  \
# 0      auto15  ...  [{'fax': '', 'type': 'primary', 'email': 'rgra...
# 1      auto15  ...  [{'fax': '3349532198', 'type': 'primary', 'ema...
# 2      auto15  ...  [{'fax': '', 'type': 'primary', 'email': 'Kiar...
# 3      auto15  ...  [{'fax': '', 'type': 'primary', 'email': 'mind...
# 4  autocustom  ...  [{'fax': None, 'type': 'primary', 'email': 'Di...
#
#                                          description organizationType  \
# 0  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 1  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 2  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 3  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
# 4  https://api.sam.gov/prod/opportunities/v1/noti...           OFFICE
#
#                                        officeAddress  \
# 0  {'zipcode': '20401', 'city': 'Washington', 'co...
# 1  {'zipcode': '36112-6334', 'city': 'MAXWELL AFB...
# 2  {'zipcode': '23297-5441', 'city': 'RICHMOND', ...
# 3  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 4  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
#
#                                   placeOfPerformance additionalInfoLink  \
# 0  {'state': {'code': 'DC', 'name': 'District of ...                NaN
# 1  {'city': {'code': '51000', 'name': 'Montgomery...                NaN
# 2  {'city': {'code': '67000', 'name': 'Richmond'}...                NaN
# 3                                                NaN                NaN
# 4                                                 {}                NaN
#
#                                               uiLink  \
# 0  https://beta.sam.gov/opp/ffe3c07bab8b4a7d9be58...
# 1  https://beta.sam.gov/opp/ff5e29951ed14b0386ea3...
# 2  https://beta.sam.gov/opp/ff2a16aad70246d1ba10e...
# 3  https://beta.sam.gov/opp/fef5aeb716414feb8c12e...
# 4  https://beta.sam.gov/opp/fed3bef7bd1e4ac389950...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 1  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 2  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 3  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 4  [{'rel': 'self', 'href': 'https://api.sam.gov/...
#
#                                        resourceLinks  \
# 0  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 1  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 2  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 3                                                NaN
# 4                                                NaN
#
#                                       cleaned_titles
# 0  Request For Information New Design Booklet Die...
# 1  Audiovisual Suite For Large Auditorium Maxwell...
# 2                           Metrology Equipment Move
# 3                          Inner Inflatable Assy Lpu
# 4                                             Cradle
#
# [5 rows x 28 columns]

# %%
df['date_posted'] = pd.to_datetime(df['postedDate'])

# %%
df.to_csv('./data/combined.csv', index=False)

# %%
# Out:
#                                noticeId  \
# 47741  ffd57f6feae54d5fbc6991c5c6431240
# 47742  ffbfccf1ec6e44b5a5fa15a66dcfff38
# 47743  ff891f139b0d41d4906ef60115a5d1b9
# 47744  ff7b65eb369041b1824256e4f16e8e81
# 47745  ff6c513eae244e5f98384ce4aabaa12d
# ...                                 ...
# 49377  006816da72d442aeac1bc7efe0afe201
# 49378  00624941e33545db91e5d132a10f7c8c
# 49379  0053c3932ac049aca98baac97e9e4b7c
# 49380  00159f16f3c94b84af124e5ceacbd914
# 49381  00124f67277e493ab43ad3658aa2fd41
#
#                                                    title   solicitationNumber  \
# 47741  35--Meet or Exceed Electronic Bartracker West ...        W911SD20R0090
# 47742          Personal Protective Equipment (Emergency)  00HCBCD9-2020-46517
'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 47745           OFFICE  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
# ...                ...                                                ...
# 49377           OFFICE  {'zipcode': '33621-5119', 'city': 'TAMPA', 'co...
# 49378           OFFICE  {'zipcode': '43218-3990', 'city': 'COLUMBUS', ...
# 49379           OFFICE  {'zipcode': '23297', 'city': 'RICHMOND', 'coun...
# 49380           OFFICE  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
# 49381           OFFICE  {'zipcode': '19111-5096', 'city': 'PHILADELPHI...
#
#                                       placeOfPerformance  additionalInfoLink  \
# 47741                                                 {}                 NaN
# 47742  {'city': {'code': '66672', 'name': 'Reston'}, ...                 NaN
# 47743                                                 {}                 NaN
# 47744                                                 {}                 NaN
# 47745                                                 {}                 NaN
# ...                                                  ...                 ...
# 49377  {'city': {'code': '71000', 'name': 'Tampa'}, '...                 NaN
# 49378                                                 {}                 NaN
# 49379                                                 {}                 NaN
# 49380                                                 {}                 NaN
# 49381                                                 {}                 NaN
#
#                                                   uiLink  \
# 47741  https://beta.sam.gov/opp/ffd57f6feae54d5fbc699...
# 47742  https://beta.sam.gov/opp/ffbfccf1ec6e44b5a5fa1...
# 47743  https://beta.sam.gov/opp/ff891f139b0d41d4906ef...
# 47744  https://beta.sam.gov/opp/ff7b65eb369041b182425...
# 47745  https://beta.sam.gov/opp/ff6c513eae244e5f98384...
# ...                                                  ...
# 49377  https://beta.sam.gov/opp/006816da72d442aeac1bc...
# 49378  https://beta.sam.gov/opp/00624941e33545db91e5d...
# 49379  https://beta.sam.gov/opp/0053c3932ac049aca98ba...
# 49380  https://beta.sam.gov/opp/00159f16f3c94b84af124...
# 49381  https://beta.sam.gov/opp/00124f67277e493ab43ad...
#
#                                                    links  \
# 47741  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 47742  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 47743  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 47744  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 47745  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# ...                                                  ...
# 49377  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 49378  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 49379  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 49380  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 49381  [{'rel': 'self', 'href': 'https://api.sam.gov/...
#
#                                            resourceLinks  \
# 47741                                                NaN
# 47742  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 47743                                                NaN
# 47744                                                NaN
# 47745                                                NaN
# ...                                                  ...
# 49377  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 49378                                                NaN
# 49379                                                NaN
# 49380                                                NaN
# 49381                                                NaN
#
#                                           cleaned_titles date_posted
# 47741    Meet Or Exceed Electronic Bartracker West Point  2020-06-03
# 47742            Personal Protective Equipment Emergency  2020-06-03
# 47743                                     Pump Hydraulic  2020-06-03
# 47744                                Wheel Pneumatic Tir  2020-06-03
# 47745                                Heating Element Ele  2020-06-03
# ...                                                  ...         ...
# 49377  Preventative Maintenance Emergency Repair Of E...  2020-06-03
# 49378                                    Battery Storage  2020-06-03
# 49379                                   Indicator Course  2020-06-03
# 49380                                Reader Magnetic Con  2020-06-03
# 49381                                Plate Set Identific  2020-06-03
#
# [1641 rows x 29 columns]

# %%
df.sort_values(by=['date_posted'], ascending = False)
# Out:
#                                noticeId  \
# 48243  b3ec96e4d2244942972e5d3ef2c453a4
# 48797  5e50474939374fe3a6db3a3fcd900459
# 48795  5e7a3b8df0434627b15e9cbcddd4640c
# 48794  5e816a799cbf4b339bb947f6a287dbf6
# 48793  5e9723cd9cb24368a53dc8c1c4fe4f6b
# ...                                 ...
# 29916  c118a891502643c3bea57d2542346671
# 29915  e034a013985e4d41b3f051d0035df53d
# 29913  fdc648579c0446f5993c5af4eb6c595d
# 29926  13f7e81d93e64c5a8e96d8e143c9507d
# 29927  0ab14328f5054d5889c44377b38d2f6a
#
#                                                    title   solicitationNumber  \
# 48243                ORPI REPLACE CG SEWER LAGOON LINERS        140P1520R0013
# 48797  J--DOOR,ACCESS,AIRCRAF, IN REPAIR/MODIFICATION OF        N0038320QM254
autocustom  ...  https://api.sam.gov/prod/opportunities/v1/noti...
# 29927  autocustom  ...  https://api.sam.gov/prod/opportunities/v1/noti...
#
#       organizationType                                      officeAddress  \
# 48243           OFFICE  {'zipcode': '86001', 'city': 'FLAGSTAFF', 'cou...
# 48797           OFFICE  {'zipcode': '19111-5098', 'city': 'PHILADELPHI...
# 48795           OFFICE  {'zipcode': '17050-0788', 'city': 'MECHANICSBU...
# 48794           OFFICE  {'zipcode': '17050-0788', 'city': 'MECHANICSBU...
# 48793           OFFICE  {'zipcode': '27909', 'city': 'ELIZABETH CTY', ...
# ...                ...                                                ...
# 29916           OFFICE  {'zipcode': '93555-6018', 'city': 'CHINA LAKE'...
# 29915           OFFICE  {'zipcode': '73145-3070', 'city': 'TINKER AFB'...
# 29913           OFFICE  {'zipcode': '29824', 'city': 'EDGEFIELD', 'cou...
# 29926           OFFICE  {'zipcode': '94123', 'city': 'SAN FRANCISCO', ...
# 29927           OFFICE  {'zipcode': '222032114', 'city': 'ARLINGTON', ...
#
#                                       placeOfPerformance  additionalInfoLink  \
# 48243  {'streetAddress': 'National Park Service, 10 O...                 NaN
# 48797                                                 {}                 NaN
# 48795                                                 {}                 NaN
# 48794                                                 {}                 NaN
# 48793  {'country': {'code': 'USA', 'name': 'UNITED ST...                 NaN
# ...                                                  ...                 ...
# 29916                                                 {}                 NaN
# 29915                                                NaN                 NaN
# 29913  {'city': {'code': '22795', 'name': 'Edgefield'...                 NaN
# 29926                                                 {}                 NaN
# 29927                                                NaN                 NaN
#
#                                                   uiLink  \
# 48243  https://beta.sam.gov/opp/b3ec96e4d2244942972e5...
# 48797  https://beta.sam.gov/opp/5e50474939374fe3a6db3...
# 48795  https://beta.sam.gov/opp/5e7a3b8df0434627b15e9...
# 48794  https://beta.sam.gov/opp/5e816a799cbf4b339bb94...
# 48793  https://beta.sam.gov/opp/5e9723cd9cb24368a53dc...
# ...                                                  ...
# 29916  https://beta.sam.gov/opp/c118a891502643c3bea57...
# 29915  https://beta.sam.gov/opp/e034a013985e4d41b3f05...
# 29913  https://beta.sam.gov/opp/fdc648579c0446f5993c5...
# 29926  https://beta.sam.gov/opp/13f7e81d93e64c5a8e96d...
# 29927  https://beta.sam.gov/opp/0ab14328f5054d5889c44...
#
#                                                    links  \
# 48243  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 48797  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 48795  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 48794  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 48793  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# ...                                                  ...
# 29916  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 29915  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 29913  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 29926  [{'rel': 'self', 'href': 'https://api.sam.gov/...
# 29927  [{'rel': 'self', 'href': 'https://api.sam.gov/...
#
#                                            resourceLinks  \
# 48243                                                NaN
# 48797                                                NaN
# 48795                                                NaN
# 48794                                                NaN
# 48793  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# ...                                                  ...
# 29916                                                NaN
# 29915  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 29913  ['https://beta.sam.gov/api/prod/opps/v3/opport...
# 29926                                                NaN
# 29927  ['https://beta.sam.gov/api/prod/opps/v3/opport...
#
#                                           cleaned_titles date_posted
# 48243                Orpi Replace Cg Sewer Lagoon Liners  2020-06-03
# 48797      Door Access Aircraf In Repair Modification Of  2020-06-03
# 48795       Manifold Hydraulic In Repair Modification Of  2020-06-03
# 48794         Battery Assembly In Repair Modification Of  2020-06-03
# 48793                        Spare Parts For Mh Aircraft  2020-06-03
# ...                                                  ...         ...
# 29916   Weapons And Systems Integration Support Services  2020-01-02
# 29915                                  Fitting Assy Fuel  2020-01-02
# 29913             Quarterly Requirements Bread Nd Qtr Fy  2020-01-02
# 29926  Replace Victorian Park Light Fixtures At Sf Marit  2020-01-02
# 29927                                               Coho  2020-01-02
#
# [50887 rows x 29 columns]
