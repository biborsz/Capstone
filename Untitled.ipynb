# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/bibor/General_Assembly/DSI/databases/FY2020_All_Contracts_Full_20200513/FY2020_All_Contracts_Full_20200514_1.csv')
# Out:
# /Users/bibor/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,24,30,39,49,53,55,56,63,72,73,87,88,95,96,97,98,115,116,144,145,159,160) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df.head(2).T
# Out:
#                                                                                                                                                           0  \
# contract_transaction_unique_key                                                                         7001_7001_70RDND19F00000009_P00002_HSHQDC14D00006_0
# contract_award_unique_key                                                                               CONT_AWD_70RDND19F00000009_7001_HSHQDC14D00006_7001
# award_id_piid                                                                                                                             70RDND19F00000009
# modification_number                                                                                                                                  P00002
# transaction_number                                                                                                                                        0
# ...

# %%
# columns the search engine will need to return - when someone is looking for competitors
columns = ['award_type', 
           'idv_type',
           'awarding_agency_name',
           'funding_sub_agency_name',
           'product_or_service_code_description',
           'naics_description', 
           'recipient_name', 
           'recipient_city_name',
           'recipient_state_code', 
           'primary_place_of_performance_city_name',
           'primary_place_of_performance_county_name', 
           'primary_place_of_performance_state_code',
           'usaspending_permalink'            
           ]

# %%
df.shape
# Out:
# (1000000, 276)
